# %% [markdown]
# <a href="https://colab.research.google.com/github/hasobi/skripsi/blob/master/scatter_dataset_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import pandas as pd

from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/My Drive/Tugas Akhir a.k.a SKRIPSI/dataset/gabungan_train_test-original.csv')
df
# Out:
#         duration protocol_type  ... num_packet   type_attack
# 0              0           tcp  ...         20        normal
# 1              0           udp  ...         15        normal
# 2              0           tcp  ...         19       neptune
# 3              0           tcp  ...         21        normal
# 4              0           tcp  ...         21        normal
# 5              0           tcp  ...         21       neptune
# 6              0           tcp  ...         21       neptune
# 7              0           tcp  ...         21       neptune
# 8              0           tcp  ...         21       neptune
# 9              0           tcp  ...         21       neptune
# 10             0           tcp  ...         21       neptune
# 11             0           tcp  ...         21       neptune
# 12             0           tcp  ...         21        normal
# 13             0           tcp  ...         15   warezclient
# ...

# %%
y=df['type_attack']
x=df['protocol_type']

# %%
plt.figure(figsize=[50,5])

plt.scatter(y, x, edgecolors='blue')
plt.xlabel('attack')
plt.ylabel('protocol')
plt.title('protocol for every type of connections')
plt.show()

# %%
service = df['service']
protocol = df['protocol_type']

# %%
plt.figure(figsize=[70,5])

plt.scatter(service, protocol, edgecolors='green')
plt.xlabel('serice')
plt.ylabel('protocol')
plt.title('protocol for every type of connections')
plt.show()

# %%
df = pd.read_csv('/content/drive/My Drive/Tugas Akhir a.k.a SKRIPSI/dataset/gabungan_train_test-original.csv')
df
# Out:
#         duration protocol_type  ... num_packet   type_attack
# 0              0           tcp  ...         20        normal
# 1              0           udp  ...         15        normal
# 2              0           tcp  ...         19       neptune
# 3              0           tcp  ...         21        normal
# 4              0           tcp  ...         21        normal
# 5              0           tcp  ...         21       neptune
# 6              0           tcp  ...         21       neptune
# 7              0           tcp  ...         21       neptune
# 8              0           tcp  ...         21       neptune
# 9              0           tcp  ...         21       neptune
# 10             0           tcp  ...         21       neptune
# 11             0           tcp  ...         21       neptune
# 12             0           tcp  ...         21        normal
# 13             0           tcp  ...         15   warezclient
# ...

# %%
attack_dict={ #DOS
    'back' : 'dos',
    'land' : 'dos',
    'neptune' : 'dos',
    'pod' : 'dos',
    'smurf' : 'dos',
    'teardrop' : 'dos',
    'apache2' : 'dos',
    'udpstorm' : 'dos',
    'processtable' : 'dos',
    'worm' : 'dos',
    'mailbomb' : 'dos',
    
    #probe
    'satan' : 'probe',
    'ipsweep' : 'probe',
    'nmap' : 'probe',
    'portsweep' : 'probe',
    'mscan' : 'probe',
    'saint' : 'probe',
    
    #R2L
    'guess_passwd' : 'r2l',
    'ftp_write' : 'r2l',
    'imap' : 'r2l',
    'phf' : 'r2l',
    'multihop' : 'r2l',
    'warezmaster' : 'r2l',
    'warezclient' : 'r2l',
    'spy' : 'r2l',
    'xlock' : 'r2l',
    'xsnoop': 'r2l',
    'snmpguess' : 'r2l',
    'snmpgetattack' : 'r2l',
    'httptunnel' : 'r2l',
    'sendmail' : 'r2l',
    'named' : 'r2l',
    
    #U2R
    'buffer_overflow' : 'u2r',
    'loadmodule' : 'u2r',
    'rootkit' : 'u2r',
    'perl' : 'u2r',
    'sqlattack' : 'u2r',
    'xterm' : 'u2r',
    'ps' : 'u2r'
}

# %%
df.replace(attack_dict, inplace = True)
df
# Out:
#         duration protocol_type  ... num_packet type_attack
# 0              0           tcp  ...         20      normal
# 1              0           udp  ...         15      normal
# 2              0           tcp  ...         19         dos
# 3              0           tcp  ...         21      normal
# 4              0           tcp  ...         21      normal
# 5              0           tcp  ...         21         dos
# 6              0           tcp  ...         21         dos
# 7              0           tcp  ...         21         dos
# 8              0           tcp  ...         21         dos
# 9              0           tcp  ...         21         dos
# 10             0           tcp  ...         21         dos
# 11             0           tcp  ...         21         dos
# 12             0           tcp  ...         21      normal
# 13             0           tcp  ...         15         r2l
# 14             0           tcp  ...         19         dos
# ...

# %%
df.type_attack.unique()
# Out:
# array(['normal', 'dos', 'r2l', 'probe', 'u2r'], dtype=object)

# %%
service = df['service']
protocol = df['type_attack']

# %%
plt.figure(figsize=[70,5])

plt.scatter(service, protocol, edgecolors='green')
plt.xlabel('serice')
plt.ylabel('protocol')
plt.title('protocol for every type of connections')
plt.show()

# %%
x=df['protocol_type']
y=df['type_attack']

# %%
plt.figure(figsize=[10,5])

plt.scatter(y, x, edgecolors='green')
plt.xlabel('service')
plt.ylabel('protocol')
plt.title('protocol for every type of connections')
plt.show()

# %%
names = df['protocol_type']
values = df['type_attack']

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
# linear
# plt.subplot(221)
plt.plot(names, values)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)
plt.show()

# %%
df = pd.read_csv('/content/drive/My Drive/Tugas Akhir a.k.a SKRIPSI/dataset/gabungan_train_test-original.csv')
df
# Out:
#         duration protocol_type  ... num_packet   type_attack
# 0              0           tcp  ...         20        normal
# 1              0           udp  ...         15        normal
# 2              0           tcp  ...         19       neptune
# 3              0           tcp  ...         21        normal
# 4              0           tcp  ...         21        normal
# 5              0           tcp  ...         21       neptune
# 6              0           tcp  ...         21       neptune
# 7              0           tcp  ...         21       neptune
# 8              0           tcp  ...         21       neptune
# 9              0           tcp  ...         21       neptune
# 10             0           tcp  ...         21       neptune
# 11             0           tcp  ...         21       neptune
# 12             0           tcp  ...         21        normal
# 13             0           tcp  ...         15   warezclient
# ...

# %%
attackNumb_dict={ #DOS
    'back' : 0,
    'land' : 0,
    'neptune' : 0,
    'pod' : 0,
    'smurf' : 0,
    'teardrop' : 0,
    'apache2' : 0,
    'udpstorm' : 0,
    'processtable' : 0,
    'worm' : 0,
    'mailbomb' : 0,
    
    #probe
    'satan' : 1,
    'ipsweep' : 1,
    'nmap' : 1,
    'portsweep' : 1,
    'mscan' : 1,
    'saint' : 1,
    
    #R2L
    'guess_passwd' : 2,
    'ftp_write' : 2,
    'imap' : 2,
    'phf' : 2,
    'multihop' : 2,
    'warezmaster' : 2,
    'warezclient' : 2,
    'spy' : 2,
    'xlock' : 2,
    'xsnoop': 2,
    'snmpguess' : 2,
    'snmpgetattack' : 2,
    'httptunnel' : 2,
    'sendmail' : 2,
    'named' : 2,
    
    #U2R
    'buffer_overflow' : 3,
    'loadmodule' : 3,
    'rootkit' : 3,
    'perl' : 3,
    'sqlattack' : 3,
    'xterm' : 3,
    'ps' : 3,
    
    #normal
    'normal' : 4
}

# %%
df.replace(attackNumb_dict, inplace = True)
df
# Out:
#         duration protocol_type  ... num_packet type_attack
# 0              0           tcp  ...         20           4
# 1              0           udp  ...         15           4
# 2              0           tcp  ...         19           0
# 3              0           tcp  ...         21           4
# 4              0           tcp  ...         21           4
# 5              0           tcp  ...         21           0
# 6              0           tcp  ...         21           0
# 7              0           tcp  ...         21           0
# 8              0           tcp  ...         21           0
# 9              0           tcp  ...         21           0
# 10             0           tcp  ...         21           0
# 11             0           tcp  ...         21           0
# 12             0           tcp  ...         21           4
# 13             0           tcp  ...         15           2
# 14             0           tcp  ...         19           0
# ...

# %%
atck=df['type_attack']
atck
# Out:
# 0         4
# 1         4
# 2         0
# 3         4
# 4         4
# 5         0
# 6         0
# 7         0
# 8         0
# 9         0
# 10        0
# 11        0
# 12        4
# 13        2
# 14        0
# 15        0
# 16        4
# 17        1
# 18        4
# 19        4
# 20        0
# 21        0
# 22        4
# 23        4
# 24        0
# 25        4
# 26        0
# 27        4
# 28        4
# 29        4
#          ..
# 173678    4
# 173679    0
# 173680    4
# 173681    0
# 173682    4
# 173683    0
# 173684    1
# 173685    1
# 173686    0
# 173687    4
# 173688    3
# 173689    0
# 173690    4
# 173691    4
# 173692    0
# 173693    4
# 173694    0
# 173695    0
# 173696    4
# 173697    4
# 173698    0
# 173699    4
# 173700    0
# 173701    0
# 173702    0
# 173703    4
# 173704    4
# 173705    0
# 173706    4
# 173707    1
# Name: type_attack, Length: 173708, dtype: int64

# %%
df2 = pd.DataFrame(atck, columns=['a', 'b', 'c', 'd'])

df2.plot.bar();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-2f5c7d622afe> in <module>()
#       1 df2 = pd.DataFrame(atck, columns=['a', 'b', 'c', 'd'])
#       2
# ----> 3 df2.plot.bar();
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in bar(self, x, y, **kwds)
#    3089             >>> ax = df.plot.bar(x='lifespan', rot=0)
#    3090         """
# -> 3091         return self(kind='bar', x=x, y=y, **kwds)
#    3092
#    3093     def barh(self, x=None, y=None, **kwds):
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
# ...
